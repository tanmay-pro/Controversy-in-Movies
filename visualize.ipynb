# %%
import networkx as nx
import matplotlib.pyplot as plt
import pickle

# Load the graph from the .pkl file
with open('./newGraphs/122898.pkl', 'rb') as f:
    graph = pickle.load(f)

# Draw the graph
print(graph)
# Out:
# Graph with 922 nodes and 263744 edges

# %%
# increase the distance between nodes
pos = nx.spring_layout(graph, k=0.5, iterations=20)
nx.draw(graph, pos, with_labels=True, node_size=1000, node_color='skyblue', font_size=8)
plt.show()
